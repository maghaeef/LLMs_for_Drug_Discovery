# %%
# -*- coding: utf-8 -*-
"""FinetuningBERT_BASE_SMILES_QLoRA_Unsloth.ipynb
This script demonstrates fine-tuning the bert-base-smiles model using 4‑bit quantization
and PEFT (QLoRA-style) with optional unsloth optimization, with a custom Trainer that
removes the unsupported "num_items_in_batch" argument, and manually computes MSE.
Before training, we group by activity type and normalize the activity values within each group.
After training, we evaluate overall test MSE as well as per-group accuracy.
"""

# Install required packages (uncomment if needed)
# !pip install datasets evaluate unsloth bitsandbytes --quiet
# !pip install --upgrade scikit-learn --quiet

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch

from transformers import (
    BertTokenizerFast,
    BertConfig,
    TrainingArguments,
    DataCollatorWithPadding,
    EvalPrediction,
    AutoModelForSequenceClassification,
    BitsAndBytesConfig,
    Trainer
)
from datasets import Dataset
# We compute MSE manually, so evaluate is not used here.

# PEFT imports (ensure your version supports fine-tuning quantized models)
from peft import LoraConfig, get_peft_model

# Try to import unsloth for extra speed optimization (if available)
try:
    from unsloth import optimize_model
    unsloth_available = True
except ImportError:
    print("Unsloth optimize_model not found. Skipping unsloth optimization.")
    unsloth_available = False
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.8/188.8 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 MB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.1/107.1 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 86.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 110.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 19.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# fastai 2.7.18 requires torch<2.6,>=1.10, but you have torch 2.6.0 which is incompatible.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.6.0 which is incompatible.
# tensorflow-metadata 1.16.1 requires protobuf<6.0.0dev,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth optimize_model not found. Skipping unsloth optimization.

# %%
# 1. Mount Google Drive and load the CSV data
from google.colab import drive
drive.mount('/content/drive')

csv_path = "/content/drive/MyDrive/DrugDiscoveryLLMs/Alzheimer_CheMBLv35_Uniprot.csv"
df = pd.read_csv(csv_path)
print("Data shape:", df.shape)

# 2. Check GPU availability
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
if device == "cuda":
    print("GPU:", torch.cuda.get_device_name(0))
# !nvidia-smi
# Out:
# Mounted at /content/drive
# <ipython-input-3-bd0bf53c5516>:6: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# Data shape: (1463277, 25)
# Using device: cuda
# GPU: Tesla T4
# Mon Feb 24 01:12:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# 3. Preprocessing data
# Select the columns of interest: 'Canonical SMILES', 'Activity Type', 'Activity Value'
df = df[['Canonical SMILES', 'Activity Type', 'Activity Value']].dropna()

# Create an input string combining SMILES and the categorical Activity Type
df["input_text"] = df["Canonical SMILES"].astype(str) + " | Activity Type: " + df["Activity Type"].astype(str)

# Group-based normalization for "Activity Value"
# We'll store group statistics (min and max) in a dictionary for later inverse transformation.
group_stats = {}
def normalize_value(row):
    act_type = row["Activity Type"]
    val = row["Activity Value"]
    if act_type not in group_stats:
        group = df[df["Activity Type"] == act_type]["Activity Value"]
        g_min = group.min()
        g_max = group.max()
        group_stats[act_type] = (g_min, g_max)
    g_min, g_max = group_stats[act_type]
    if g_max == g_min:
        return 0.0
    return (val - g_min) / (g_max - g_min)

df["labels"] = df.apply(normalize_value, axis=1).astype(float)
print("Group stats (min, max) per Activity Type:")
group_stats
# Out:
# Group stats (min, max) per Activity Type:
# {'IC50': (-7000.0, 8.912509381337441e+23),
#  'Inhibition': (-524.9, 500000.0),
#  'Ki': (-10.0, 1e+24),
#  'Relative potency': (0.0, 34000000000.0),
#  'ED50': (8.4e-06, 100000.0),
#  'Inhibition potency': (0.002, 200.0),
#  'K inact': (0.00067, 780.0),
#  'Km': (0.12, 15900000000000.0),
#  'Ks app': (0.01, 0.13),
#  'Reduction': (-80.0, 86.0),
#  'Relative Potency': (0.16, 126.8),
#  'Activity': (-399.0, 761592.0),
#  'Ki app': (35.0, 472.0),
#  'Ka app': (0.13, 0.28),
#  'kinact': (0.00036, 7.7),
#  'Activity remaning': (41.0, 97.0),
#  'Ks': (1.7e-06, 785.0),
#  'Ratio': (-4.24, 1000000000.0),
#  'k cat': (0.0007, 1292.0),
#  'Effect': (0.0, 363.4),
#  'RP': (1.0, 451.2),
#  'Log IC50': (0.01, 25.0),
#  'Km/Ki': (0.087, 1.51),
#  'Ratio LC50/IC50': (333.0, 2273.0),
#  'Ratio IC50': (-8.0, 540000.0),
#  'AC50': (0.1, 1000000000.0),
#  'Kinact': (0.0, 10000.0),
#  'INH': (-3.0, 50000.0),
#  'Vmax': (0.0, 123000000000.0),
#  'pIC50': (-2.176, 1.509),
#  'Imax': (0.0, 661.0),
#  'T1/2': (0.0005556, 995.0),
#  'deltaG': (-60.65, 271.04),
#  'EC50': (0.0, 5.754399373371543e+17),
#  'ED': (0.3, 2.3),
#  'Control': (0.0, 472.0),
#  'EDmin': (0.01, 134.0),
#  'Mean': (124.0, 202.0),
#  'Kd': (2.7e-13, 1000000000.0),
#  'Kb': (0.0, 900000.0),
#  'Bmax': (0.003, 55500.0),
#  'pKB': (4.5, 10.2),
#  'Relative affinity': (-2.93, 59700.0),
#  'Emax,diss': (25.0, 100.0),
#  '-Log KD': (4.61, 9.41),
#  '-Log ED50': (4.07, 6.87),
#  'Intrinsic activity': (-59.0, 205.0),
#  'PD2': (6.69, 6.73),
#  'Palpha': (-2.0, 1.07),
#  'RM': (0.76, 1.16),
#  'Relative efficacy': (0.2, 99.0),
#  'pD2': (3.0, 100.0),
#  'pEC0.5,diss': (2.98, 6.87),
#  'pKA': (3.55, 8.29),
#  'pKb': (3.75, 10.6),
#  'Receptor occupied': (0.86, 7.36),
#  'Affinity': (0.0072, 45000.0),
#  'CCh': (0.4, 293.0),
#  'Cooperativity': (0.2, 3000.0),
#  'Max cAMP': (41.0, 119.0),
#  'Log 1/M': (4.57, 7.21),
#  'Max': (0.0, 312.0),
#  'p[A50]': (3.9, 9.7),
#  'Increase': (-11.1, 978.0),
#  '-logKa': (4.64, 8.29),
#  'EC80': (10.0, 10.0),
#  'Emax': (-178.0, 4941.0),
#  'Efficacy': (-51.0, 10000.0),
#  '%max': (0.0, 3860.0),
#  'Emin': (0.0, 130.0),
#  'K': (0.0, 17500000.0),
#  'pK': (6.36, 10.46),
#  'FC': (-2.3, 30286.0),
#  '% Inhibition of Control Specific Binding (Mean n=2)': (-104.0, 99.1),
#  '% Ctrl': (-2.0, 190.0),
#  'Mean fold stimulation': (0.125, 5.325),
#  'effect': (-13.85, 69.05),
#  '% of inhibition': (-96.58, 110.0),
#  '% of inhibition or stimulation': (70.0, 100.0),
#  '% of control': (-13.35, 129.0),
#  'pXC50': (4.0, 5.4),
#  'EC0.25': (6.1, 119.0),
#  'pEC0.5': (5.49, 8.65),
#  'p alphaKa': (5.0, 8.66),
#  'pAlpha': (-1.38, 0.56),
#  'nH': (0.54, 1.7),
#  'p alpha': (-0.35, 0.56),
#  'pEC50 diss': (5.87, 8.36),
#  'EC25': (45.0, 112.0),
#  'ED delta': (30.0, 30.0),
#  'MED': (1e-11, 100.0),
#  'KH': (6.9e-15, 4.1),
#  'KL': (1.2e-09, 390000.0),
#  'sigmaH': (12.0, 49.5),
#  'sigmaSH': (23.3, 39.0),
#  'Response': (-5.0, 105.0),
#  'sigmaL': (16.4, 86.0),
#  'Hill coefficient': (0.47, 3.63),
#  'K 0.5': (0.37, 33400.0),
#  'K H': (64.0, 12240.0),
#  'K L': (2095.0, 188300.0),
#  'K SH': (5.5, 703.0),
#  'K app': (4.3e-05, 22000.0),
#  'Selectivity ratio': (-4.7, 1000000.0),
#  'Selectivity': (-1.447, 71000.0),
#  'Ratio Ki': (-16.5, 60000.0),
#  'Selectivity Index': (0.002, 11800.0),
#  'Max effect': (17.0, 100.0),
#  'Max stimulation': (0.0, 99.0),
#  'pKi': (0.004, 8.34),
#  'Delta pKi': (-3.0, -0.1),
#  'Log Ki': (-0.66, 44.3),
#  'Agonist': (0.0, 149.0),
#  'Stimulation': (0.0, 6893.0),
#  'Ratio EC50': (0.0015, 10000.0),
#  'logKi': (-0.155, 1.645),
#  'Potency': (0.01, 89125093.8),
#  'Ke': (2.5, 10000.0),
#  'log(activity)': (-1.36, 8.53),
#  'Ki 0.5': (0.3, 5000.0),
#  'Agonist effect': (0.0, 42.0),
#  'pKa': (0.0, 9.54),
#  'E': (0.48, 80.0),
#  'max activation': (0.11, 950.0),
#  'ID50': (1.4e-08, 1000.0),
#  'Drug metabolism': (-50.0, 391000.0),
#  'Drug degradation': (0.06, 9810.0),
#  'TIME': (0.0, 408.0),
#  'Kcat': (0.06, 1719.0),
#  'Kcat/Km': (0.001, 560000.0),
#  '% Enzyme Activity (relative to DMSO controls, average n=2)': (94.21, 106.64),
#  'Control compound IC50': (4.917e-05, 0.9021),
#  'Ka': (0.011, 278000000000.0),
#  'K ass': (0.0, 3000000000.0),
#  'Rate': (0.33, 1185.0),
#  'Ks/i': (0.01, 466.0),
#  'ka': (0.24, 6700.0),
#  'ka/Ki': (0.12, 1185.0),
#  'IC50 ratio': (0.06, 510.0),
#  'IC90': (0.81, 110000.0),
#  'IC95': (0.2, 6600.0),
#  'Stability': (0.12, 109.0),
#  'k_obs': (0.0002505, 2087.5),
#  "Ki'": (150.0, 150.0),
#  'Reactivity': (5.0, 753.0),
#  'PI metabolism': (-3.0, 100.0),
#  'Smax': (2.0, 1300.0),
#  'Stimulations': (40.0, 40.0),
#  'Basal control': (79.0, 109.0),
#  'inhibition (at 100uM)': (11.0, 11.0),
#  'KA': (0.011, 351000000000.0),
#  'PI': (2.0, 107.0),
#  'Max PI': (0.0, 156.0),
#  'Dissociation rate constant': (0.72, 14.6),
#  'IP': (0.0, 600000.0),
#  'logKd': (4.12, 8.13),
#  'pKx': (4.59, 6.92),
#  'logEmax': (0.17, 0.61),
#  'log(IA)': (-3.0, 1.36),
#  'Occ': (16.2, 98.8),
#  '% Inhibition of Control Agonist Response (Mean n=2)': (-31.6, 57.0),
#  '% of Control Agonist Response (Mean n=2)': (-13.0, 12.8),
#  'Inhibition (% of control)': (-16.0, 32.0),
#  'Activation (% of control)': (-3.0, 23.0),
#  'Potentiation inflection point': (136.0, 10000.0),
#  'Agonism inflection point': (7379.0, 7379.0),
#  'Relative response': (32.1, 102.0),
#  'Efficiency': (30.0, 132.0),
#  'Kapp': (0.00048, 1400000.0),
#  'Duration': (0.0, 7.0),
#  'Agonist activity': (0.1, 184.0),
#  'Blood pressure': (0.0, 80.0),
#  'ED2': (0.075, 6.5),
#  'pAh': (6.0, 6.2),
#  'Displacement': (0.0, 7200.0),
#  'Biological activity': (0.0, 100.0),
#  'ER': (27.0, 123.0),
#  'FSC recovery': (-15.0, 121.0),
#  'Antagonist efficacy': (100.0, 100.0),
#  'pKD': (4.0, 10.06),
#  'Others': (134.0, 134.0),
#  'cAMP': (7.4, 29.7),
#  'cAMP increase': (25.0, 96.0),
#  'Ki ratio': (0.0007, 4500.0),
#  'IA': (0.0, 166.0),
#  'Maximal effect': (90.3, 90.3),
#  'Change': (-100.0, 389.0),
#  'Basal': (10.08, 19.29),
#  'K1': (2.2, 4614.0),
#  'KiAH': (0.011, 166.0),
#  'pK1': (4.0, 8.66),
#  'Accumulation': (31.0, 125.0),
#  'Behavioral effect': (0.0, 5.0),
#  'No. of rats': (0.0, 42.0),
#  'Turnover': (51.0, 122.0),
#  'Change in body temperature': (-3.61, 3.05),
#  'IC60': (6.9, 100000.0),
#  'Concentration': (8.7e-10, 800000.0),
#  'MIC50': (300.0, 30000.0),
#  '% Inhibition of Control Values': (-23.1, 90.6),
#  'log(10^6/IC50)': (2.15, 6.3),
#  'Inhibition ratio': (2.0, 69.0),
#  'DOSE': (0.625, 1884.0),
#  'Max response': (8.0, 264.0),
#  'Fold activation': (0.17, 331.0),
#  'MEC': (0.3, 500.0),
#  'Transactivation': (0.17, 410.0),
#  'Fold induction': (3.2, 6.2),
#  'CTF': (9.11, 100.0),
#  'Maximal activation': (0.11, 1650.0),
#  'Max. activation': (19.0, 100.0),
#  'Response unit': (92.0, 734.2),
#  'Fold change': (0.8, 27.2),
#  'XC50': (2500.0, 20000.0),
#  'RLU': (0.82, 78.56),
#  'deltaT': (-0.3, 6.4),
#  'Tm': (-0.6, 65.8),
#  'T': (46.4, 94.0),
#  'Alpha max': (0.0, 100.0),
#  'Delta Tm': (-4.5, 151.0),
#  'k_off': (0.0, 2.75),
#  'k_on': (0.01303, 1600000.0),
#  'Fold selectivity': (1.0, 700.0),
#  'Residual activity': (0.0, 396.0),
#  '% Control': (0.0, 100.0),
#  '% residual kinase activity': (17.0, 141.0),
#  '% Residual activity with Skepinone-L': (77.0, 132.0),
#  '% Activity remaining': (19.02, 124.38),
#  '% binding': (41.0, 100.0),
#  'Residual_activity': (25.0, 100.0),
#  'C50': (0.92, 100.0),
#  'Inihibition': (2.0, 31.0),
#  'Residual Activity': (-12.0, 322.0),
#  'GI50': (0.21, 22600.0),
#  'log2FC': (-0.87, 4.108),
#  'DC50': (0.002, 1000.0),
#  '% of residual activity': (36.0, 104.0),
#  'fold selectivity': (11.0, 17000.0),
#  '% of engagement': (-19.4, 41.8),
#  'ED90': (5.0, 20.0),
#  'BP': (10.2, 10.2),
#  'pA2': (7.5, 9.0),
#  'Binding': (0.0, 12693.0),
#  'n': (1.78, 2.24),
#  'Log B/F': (-2.886, 3.222),
#  "Log K'": (0.0, 2.69),
#  'Binding affinity': (0.0, 1149.0),
#  'HSAI': (1.0, 837.0),
#  'Binding constant': (500000.0, 5000000.0),
#  'k2': (0.0006, 2640000.0),
#  "k'/k'+1": (0.21, 0.98),
#  'PPB': (0.0, 100.0),
#  'KD1': (24.0, 495.0),
#  'KD2': (6.0, 2114.0),
#  'logKA': (-0.314, 1.436),
#  '%Bound_Albumin': (41.8, 41.8),
#  'log Ks': (2.65, 6.87),
#  'KSV': (0.0103, 529.2),
#  'Fu': (0.002, 0.7458),
#  'log(PB)': (0.45, 1.97),
#  'Kq': (0.1, 52.92),
#  'deltaH': (-36893.0, 139.02),
#  'Vmax/Km': (0.00052, 1298.0),
#  'deltaS': (-490.91, 96.76),
#  'logKb': (6.75, 7.02),
#  'Time': (0.488, 6.858),
#  'logFu': (-3.28, -0.56),
#  'PB': (0.12, 24.1),
#  '-TdeltaS': (-33.0, 435.73),
#  'TdeltaS': (-24.91, 6.39),
#  'RSA tR': (12.1, 141.2),
#  'Amount bound': (0.36, 19.3),
#  'Log 1/C': (2.38, 8.38),
#  'Relative florescence': (3.3, 23.1),
#  'Carbonyl group': (1.55, 4.38),
#  'Kdiss': (0.007, 2680.0),
#  'Solubility': (0.6, 84.0),
#  'log K': (0.7, 5.0),
#  'Retention_time': (2.4, 34.0),
#  'AE activity': (18.0, 36.0),
#  'pC2A': (-0.892, 1.745),
#  'I': (0.0, 82.7),
#  'Potency ratio': (0.000484, 12.0),
#  'Alloste ic enhan er (AE)': (0.0, 3.4),
#  'Kbapp': (0.47, 644.0),
#  'KiH': (1.6, 217.0),
#  'KiL': (0.68, 26.0),
#  'koff': (0.004, 2.148),
#  'kon': (5e-05, 27200000.0),
#  'Loss': (44.0, 65.0),
#  'pKi(uM)': (-2.22, -0.12),
#  'Inhibition (at concentration M)': (10.0, 37.0),
#  'RBA': (0.0, 17300.0),
#  'Relative binding affinity': (-0.7, 2100.0),
#  'RSA': (0.0, 418.0),
#  'FI5': (13.0, 10000.0),
#  'EC150': (0.4, 4077.0),
#  'EC5': (0.002, 10000.0),
#  'Relative seminal vesicle weight': (38.3, 200.0),
#  'GI': (0.08, 132.0),
#  'Relative activity': (0.0, 100.0),
#  'Competition factor': (8.9, 266.0),
#  'Anogenital distance': (1.46, 2.0),
#  'ED50 mg/animal/day': (1.3, 1.6),
#  'Organ weight': (6.0, 47.0),
#  'Tp control': (14.0, 138.0),
#  'Relative antiandrogenic activity': (1.0, 1.0),
#  'Specific activity': (0.5, 57.0),
#  'BSI': (5.6, 648.0),
#  'RAC': (4e-05, 300.0),
#  'Covalent binding': (10.0, 10.0),
#  'Dose': (0.2, 600.0),
#  'E2 response': (0.0, 100.0),
#  'Estrogenic effect': (-19.4, 500.0),
#  'Induction': (1.0, 84.0),
#  'Oligo shifted': (38.0, 93.0),
#  'E2': (1.0, 100.0),
#  'T/C': (-25.0, 205.0),
#  'Activation': (-5.0, 275.0),
#  'Absolute ratio': (0.12, 29.0),
#  'Inhibition (alpha = 0.01)': (27.0, 36.0),
#  'Uterotrophic effect': (0.04, 244.0),
#  'Uterus effect': (69.1, 188.5),
#  'Vaginal activity': (0.38, 50.0),
#  'Weight': (-121.2, 131.8),
#  'Cell number': (11.2, 11.2),
#  'Anti-uterotrophic effect': (28.8, 53.5),
#  'Relative uterus weight': (8.9, 60.5),
#  'Relative uterine weight': (6.4, 69.3),
#  'Uterine weight': (2.9, 203.4),
#  'Weight (mg/g)': (30.8, 30.8),
#  'Bone mineral density': (386.2, 592.0),
#  'BMD': (436.0, 565.0),
#  'Wet weight': (26.2, 53.8),
#  'A50': (4e-09, 5e-06),
#  'Estrogenic potency': (0.0, 2000.0),
#  'NSB': (0.39, 2.86),
#  'Antiuterotropic effect': (15.2, 21.6),
#  'Agonistic activity': (15.0, 100.0),
#  'Antagonism': (-4.0, 100.0),
#  'Decrease': (3.69, 55.69),
#  'Infertility activity': (150.0, 150.0),
#  'Max uterine weight': (41.8, 97.0),
#  'Mean weight': (8.7, 59.0),
#  'Relative uterotrophic activity': (0.1, 100.0),
#  'Uterotropic activity': (0.0, 10.5),
#  'Uterotropic effect': (5.7, 24.0),
#  'Uterine wet weight': (15.8, 60.3),
#  'S/N': (2.3, 13.5),
#  'Gain': (2.91, 440.68),
#  'Uterine activity': (0.0, 100.0),
#  'RBA1': (0.04, 126.0),
#  'RBA2': (0.01, 243.0),
#  'RA': (-2.0, 112.0),
#  'RAC app': (0.0076, 100.0),
#  'Inactivation': (24.0, 70.0),
#  'RE': (0.0019, 1.0),
#  'pKm': (3.0, 5.1),
#  'k obs / 1': (0.0, 600000.0),
#  'K obs / 1': (25.0, 1500000.0),
#  'IC100': (25.0, 25.0),
#  'k3/Ki': (0.0, 40250000.0),
#  'k3/ki': (0.0, 168736.0),
#  'IC25': (10.0, 2000.0),
#  'CI': (0.051, 1.38),
#  'Koff': (1.3, 5.69),
#  'Hypotensive activity': (19.0, 48.0),
#  'Specific binding': (0.31, 93.4),
#  'Bmax1': (8.0, 674.0),
#  'Kd1': (0.006, 380.0),
#  'Bmax2': (17.0, 1330.0),
#  'Kd2': (1.0, 6180.0),
#  'IS': (2952.0, 50256.0),
#  'RRT': (340.0, 340.0),
#  'EI': (0.3, 0.96),
#  'NO formation': (0.5, 100.0),
#  'NOHA': (0.2, 98.0),
#  'Initial rates': (0.5, 100.0),
#  'Survival': (0.0, 264.0),
#  'MIC': (0.003, 130000.0),
#  'nNOS activity': (31.51, 105.32),
#  'Selectivity index': (0.0085, 646153.0),
#  'Flu intensity': (0.3, 3004.0),
#  'AT1 affinity': (0.1, 280.0),
#  'log(1/C)': (-2.946, 0.301),
#  '%Max (Mean)': (-69.24, 195.4),
#  '%Inhib (Mean)': (-1072.24, 121.64),
#  'Intrinsic efficacy': (49.0, 105.0),
#  'Maximum response': (35.0, 100.0),
#  'log(ratio)': (0.05, 9.85),
#  '% Inhibition of Control Specific Binding': (-2.4, 1.9),
#  'Rmax': (0.0, 1000.0),
#  'fpKi': (4.6, 4.6),
#  'K aff': (32.0, 165.0),
#  'Affinity ratio': (0.016, 1472.0),
#  'Ke(app)': (9.2, 10000.0),
#  'pKp': (6.35, 8.4),
#  '-Log KB': (6.37, 8.14),
#  'K0.5': (0.3, 10000.0),
#  'TN': (4.17, 443.0),
#  'Ri': (1.9, 1.9),
#  'Vmax / Km': (2.38, 5568.0),
#  'KiA': (0.0016, 0.39),
#  'k cat/Km': (0.000213, 2130000.0),
#  'ED80': (8.0, 8.0),
#  'Reversible': (0.0, 100.0),
#  'Kic': (0.0097, 7151000.0),
#  'Specificity': (0.0, 100000.0),
#  'k3': (9.0, 850000.0),
#  'K obs': (0.0322, 100.01),
#  'Vmax(app)': (0.02, 68.18),
#  'Kobs': (0.447, 3.752),
#  "k2'": (2.55e-05, 9.38),
#  'k2c': (0.03, 5.78),
#  'kn': (4.38, 75.0),
#  'Reactivation': (0.0, 109.0),
#  'kHOX': (0.0, 8680.0),
#  'kr': (0.0, 77700.0),
#  'Fold IC50': (15.0, 15.0),
#  'KHOX': (38.2, 482.0),
#  'Kc': (2.5e-07, 7.3e-07),
#  'Kr': (0.0, 9370000.0),
#  'Relative Selectivity': (0.13, 32.14),
#  'kOX': (0.0, 11500.0),
#  '1/kmax': (15.0, 117.0),
#  '1/kobsd-ka': (8.13, 538.0),
#  'Kr/kmax': (1.7, 330.0),
#  "[EOP']infinity/[EOH]infinity": (0.122, 3.29),
#  'ka/kr': (-0.018, 0.21),
#  'kaKr/kr': (75.0, 32000.0),
#  'kb': (30.0, 5500.0),
#  'k eff': (11.0, 1600.0),
#  'k eff (rel)': (1.0, 145.0),
#  'KOX': (0.94, 15260.0),
#  'EC30': (0.016, 42.0),
#  'k-2': (0.35, 5.0),
#  'logRA': (-2.298, 3.045),
#  'IC33': (30.0, 30.0),
#  'logIC50': (-1.1, 4.614),
#  'alphaKi': (8.95, 139000.0),
#  '% Inhibition of Control Values (Mean n=2)': (-94.0, 78.1),
#  'IZ': (8.0, 55.0),
#  "KI'": (4.1, 13.0),
#  'Reversibility': (2.59, 17.8),
#  'No. of survivors': (0.0, 10.0),
#  'K diss': (24.0, 280.0),
#  'KR': (3.0, 575.0),
#  'kR': (0.007, 0.0324),
#  'I10': (0.0006, 0.0006),
#  'pKic': (4.54, 4.8),
#  'pKinc': (4.0, 5.47),
#  'Relative activity of AChE': (46.0, 102.0),
#  'Kiuc': (0.8, 69.56),
#  'EC24': (250.0, 250.0),
#  'ED20': (11.0, 3000.0),
#  'Log 1/KL': (-5.59, -1.92),
#  'Log 1/Kd': (-4.74, 2.58),
#  'log(Tau/KA)': (0.0, 41.5),
#  'K bind': (0.0051, 10000.0),
#  'K Bind': (0.043, 50.0),
#  '-Log K0.5': (5.46, 9.4),
#  'Log Kd': (-11.43, -11.43),
#  'K inact/Ki': (13.0, 66680.0),
#  'Delta G': (-11.9, 4.59),
#  'Enzyme inhibition': (8.0, 61.0),
#  '-log(RatioIC50)': (-3.2, 0.609),
#  'IC80': (1.0, 370.0),
#  '% of effect': (21.0, 21.0),
#  'COI': (1.0, 90.0),
#  'Reversal activity': (0.0, 92.0),
#  'Inhibitory activity': (0.03, 570.0),
#  'pEC5': (5.0, 5.0),
#  'pC30': (6.22, 6.22),
#  'Discrimination ratio': (0.25, 6.5),
#  'IC5': (0.2, 10000.0),
#  'Log potency ratio': (-3.89, 2.9),
#  'DA release': (0.04, 31.0),
#  'Uptake/Binding ratio': (0.2, 3.8),
#  'log(%)': (0.0, 2.0),
#  'fIC50': (0.06, 288.0),
#  'RUmax': (0.0, 272.13),
#  'EC2x': (2.0, 300.0),
#  'EC5x': (10.0, 160.0),
#  'SC50': (85.0, 85.0),
#  'logEC50': (5.2, 7.8),
#  'EC': (23.29, 5000.0),
#  'Kieq': (0.023, 7400.0),
#  'Inverse agonism': (38.3, 38.3),
#  'pEC50': (0.06, 0.06),
#  'LED': (0.5, 30.0),
#  'k2/Ki': (0.0, 17000.0),
#  'kirr': (0.061, 0.36),
#  'K2': (0.037, 36000.0),
#  "Ki''": (0.091, 25.0),
#  'Degradation': (0.0, 141.0),
#  'k/K': (700.0, 230000.0),
#  'ki/Ki': (11.0, 4692.0),
#  'RFU': (-6.56, 105300.0),
#  'pA10': (3.74, 7.93),
#  'ISA': (0.04, 1.0),
#  'Binding activity': (1.0, 10000.0),
#  'Blockade': (3.7, 377.0),
#  'ED30': (5.0, 1000.0),
#  'BEI': (14.8, 32.7),
#  'IC20': (0.06, 50.0),
#  'Kinact/Ki': (0.19, 6.3),
#  'Rate of oxidation': (0.0, 25.87),
#  'Control of P-450 marker': (100.9, 103.1),
#  'Partition ratio': (99.0, 99.0),
#  'TDI': (0.9, 60.0),
#  'CL': (0.0, 74.4),
#  'Compound recovery': (0.33, 98.1),
#  'Fm': (2.6, 2.6),
#  'IC': (0.5, 50.0),
#  'cholesterol level': (150.0, 179.0),
#  'Suppression': (26.0, 39.0),
#  'pKact': (8.33, 8.47),
#  'KB': (1.12, 4.73),
#  'ACT': (3.0, 25.0),
#  '-Delta G': (6.0, 15.25),
#  'PR': (0.01, 150.0),
#  'IA50': (4.0, 82.0),
#  'KD app': (0.037, 6.47),
#  'cAMP production': (24.0, 122.0),
#  'Vasodilation': (4.82, 7.95),
#  'DR10': (0.03, 16.8),
#  "KD'": (4e-09, 3.9),
#  'Affinity constant': (4e-05, 10.0),
#  'pA2 - pA10': (0.5, 0.93),
#  'p[A]50': (5.0, 9.4),
#  'Beta2 duration': (18.0, 1080.0),
#  'IAR': (0.86, 0.98),
#  'pA50': (6.7, 8.8),
#  'pA2(app)': (5.2, 9.23),
#  'KB app': (0.124, 30.1),
#  'Xi50': (0.00029, 0.058),
#  'Mole fraction': (0.057, 53.0),
#  'EC90': (97.0, 407.0),
#  'HTS data': (0.0, 100.0),
#  'Relative activation': (-1.0, 112.0),
#  'RBA data': (-1.25, 2.6),
#  'RTP': (0.002, 100.0),
#  'REP': (0.0039, 100.0),
#  'MFI': (-20.0, 1590.0),
#  'log(RBA)': (-0.63, 2.67),
#  'pC1': (0.156, 1391.0),
#  'G-protein activation': (85.0, 325.0),
#  'GTP-gammaS index': (0.02, 1.0),
#  'IAr': (-0.18, 1.0),
#  'Relative intrinsic activity': (-0.066, 1.0),
#  'pRA': (-4.78, 1.7),
#  'pRA1': (-3.83, 1.03),
#  'ECmax': (37.0, 101.0),
#  'cAMP activity index': (0.0, 1.45),
#  'Log KH': (-14.49, -9.09),
#  'Log KL': (-10.05, 10.36),
#  'Index': (0.0, 1.45),
#  'pKi1-pKi2': (-2.17, 1.58),
#  'Ratio pKi': (-0.14, 17.0),
#  'deltaTm': (0.1, 20.0),
#  'K cat/Kinact': (8300.0, 8300.0),
#  'Residual peptide': (0.0, 460.0),
#  'Time to max. inhibition': (0.2, 3.0),
#  'Mean decrease': (13.0, 92.0),
#  'Mean duration': (0.0, 105.0),
#  'T50': (2.0, 180.0),
#  'Delta MABP': (-41.0, 28.0),
#  'Delta blood pressure': (5.0, 60.0),
#  'Enhancement': (7.0, 200.0),
#  'Max intensity': (6.6, 22.7),
#  'Total turnings': (150.0, 3590.0),
#  'Total binding inhibited': (15.0, 50.0),
#  'Dopamine level': (2.7, 6.5),
#  'Muscarinic receptor affinity': (0.01, 1.0),
#  'RBI': (0.6, 155.0),
#  'Muscarinic agonist index': (3.0, 540.0),
#  'Efficacy ratio': (3.0, 4068.0),
#  'Max contraction': (0.0, 100.0),
#  'EPMR': (0.42, 73.9),
#  'K-1': (0.079, 0.108),
#  'K-2': (0.013, 0.025),
#  'Analgesic efficacy': (21.0, 101.0),
#  '% inhibition': (-94.7, 900.0),
#  'Tlag': (2.7, 82.7),
#  'Occupancy': (17.0, 59.0),
#  'EC12': (0.11, 100.0),
#  'EC15': (0.134, 2.317),
#  'Blockage': (100.0, 100.0),
#  'K6': (4e-05, 0.021),
#  'k': (97.0, 956.0),
#  'A2': (0.76, 1.1),
#  'Release': (10.0, 90.0),
#  'MPO release': (0.27, 200.0),
#  'MEC1.5': (1.0, 1000.0),
#  'MEC2.0': (10.0, 820.0),
#  'RU': (0.3, 1.9),
#  'Delta TM': (-11.62, 21.03),
#  'delta Tm': (-5.549, 0.8446),
#  'delta Tm Staurosporine positive control': (-2.913, 12.08),
#  'Kdapp': (9.0, 62.0),
#  'dTM': (-2.3, 2.4),
#  'OD': (0.219, 0.662),
#  'PCMA antagonism': (0.0, 6.0),
#  'No. of uptake sites': (12.3, 15.6),
#  'Delta HDL': (5.0, 388.0),
#  'Delta TC': (-80.0, 46.0),
#  'LS': (15.0, 137.0),
#  'SS': (32.0, 165.0),
#  'Serum lipoprotein cholesterol': (32.6, 184.5),
#  'ACAT activity': (535.0, 535.0),
#  'COF': (1262.0, 69317.0),
#  'Relative JC-1 accumulation': (0.0, 91.0),
#  'Binding site fraction': (0.2, 0.8),
#  'Pgp AbA/analogue ratio': (0.016, 12.5),
#  'Inhibitory activity ratio': (1.18, 9.5),
#  'Inhibitory ratio': (7.27, 7.27),
#  'Transport': (8.3, 28.3),
#  'Fluorescence intensity': (11.2, 1029.4),
#  'FICI': (0.062, 12.16),
#  'permeability': (0.0129, 38.9),
#  'Papp': (0.21, 990.0),
#  'Recovery': (0.0, 110.1),
#  'Mem Rec': (76.1, 88.4),
#  'Calculated Ratio': (-0.49, 0.45),
#  'B-A/A-B': (0.8, 2.6),
#  'Ratio_Papp': (0.67, 165.0),
#  'Ratio_ATPase activity': (0.23, 12.1),
#  '% maximum response': (-6.22, 102.0),
#  'EC200': (0.035, 0.3),
#  'Ki1': (0.11, 200.0),
#  'Ki2': (3.4, 3200.0),
#  'AQ': (0.21, 0.62),
#  'mortality': (100.0, 100.0),
#  'Drug uptake': (3.08, 5.09),
#  'RatioGI50': (0.5, 32.0),
#  'I0.5': (0.01, 1.6),
#  'FI': (28.97, 36.07),
#  'CI50': (0.082, 1.03),
#  'Rate of inhibition': (2.2, 10.3),
#  'Fold stimulation': (1.3, 3.2),
#  'Thermal melting change': (-11.5, 16.3),
#  'Peak current': (0.9, 60.4),
#  'cKi': (0.08, 2.5),
#  '% of activity': (90.0, 90.0),
#  'KI50': (0.001, 0.001),
#  'Ratio pIC50': (-2.09, 2570.0),
#  'Selectivity coefficient': (0.05, 74.33),
#  'MAO deamination': (1.0, 78.0),
#  'SI': (0.0057, 2500.0),
#  'Fibril formation': (1.0, 100.0),
#  'Formation': (0.0, 100.0),
#  'Aggregate': (7.0, 24.0),
#  'Tetramer': (76.0, 95.0),
#  'KPCB': (7.5e-06, 100.0),
#  'KT4': (7.39e-07, 9.93),
#  'Ka(T4)': (0.3, 28.7),
#  'Plasma selectivity': (0.07, 1.96),
#  'Monomer': (5.0, 5.0),
#  'Binding stoichiometry': (0.5, 1.86),
#  'Molar equivalence bound': (0.49, 0.68),
#  'Activity_index': (0.0, 5.8),
#  'Uptake ratio': (0.37, 68.9),
#  'pRatio': (8.0, 8.0),
#  'fIC90': (0.535, 2.2),
#  'Potency_Dyrk1a_uM': (0.026, 50.0),
#  'Tm shift': (-1.0, -1.0),
#  'S20,w': (3.09, 3.09),
#  'Kis': (0.7, 58000.0),
#  'Total binding': (40.0, 62.0),
#  'Avoidance response': (45.9, 289.0),
#  'fEC50': (64.0, 64.0),
#  'A/Ad': (0.2, 200000.0),
#  'Transcriptional activity': (8.0, 213.0),
#  'PC50': (0.14, 30.0),
#  'Ratio ED50': (0.0005, 1000000.0),
#  'RCI': (38.0, 147.0),
#  'Binding potency': (1.0, 1.0),
#  'Relative binding potency': (0.003, 1.0),
#  'VDR affinity': (0.02, 200.0),
#  'Max binding': (9.0, 71.0),
#  'kH': (13.8, 13.8),
#  'Relative rate of hydrolysis': (0.0, 264.2),
#  'Rate of hydrolysis': (0.0, 3.43),
#  'Max inhibition': (19.0, 100.0),
#  'Hydrolysis': (12.0, 100.0),
#  'Log I50': (4.0, 5.8),
#  'Rate of reduction': (0.22, 35.6),
#  'Substrate specificity': (0.0, 52.7),
#  'Enzyme activity': (0.0, 100.0),
#  'Metabolism': (0.04, 77.6),
#  'Log CDQR': (-0.602, 1.903),
#  'MET': (0.1, 263.0),
#  'CD': (0.01, 64.0),
#  'pI50': (2.78, 6.82),
#  'Kii': (0.8, 37000.0),
#  'Epinephrine level': (5.8, 8.0),
#  'Fe removed': (0.0, 50.0),
#  'DeltaCp': (-0.86, -0.31),
#  'pIC25': (10.2, 10.2),
#  'Selectivity ratio S3/2': (0.0, 290.0),
#  'Kina': (0.025, 0.097),
#  'Superoxide anion': (45.0, 60.0),
#  'SB': (100.0, 100.0),
#  'Alpha': (0.0, 0.0),
#  'AUC': (173.3, 1219.47),
#  'Max. potentiation': (150.0, 350.0),
#  'PF50': (0.6, 5000.0),
#  'Acetylation': (3.0, 100.0),
#  'KII': (1.38, 9.21),
#  'KIs': (1.2, 8.16),
#  'CC50': (6759.0, 49750.0),
#  'EC70': (3.9, 3.9),
#  'AIDH activity': (13.4, 28.3),
#  'AlDH activity': (73.8, 73.8),
#  'MA': (44.0, 169.0),
#  'pKinact': (2.34, 2.61),
#  'LC50': (1.0, 50000.0),
#  'Ratio Ki(app)': (2.0, 300.0),
#  'ICmax': (10.0, 95.0),
#  'Kd,app': (37.9, 37.9),
#  'EC1.5': (0.16, 100.0),
#  'V1/2': (-28.8, -21.4),
#  'Antiovulatory activity': (0.0, 100.0),
#  'Full inhibition': (3.0, 3.0),
#  'MRT': (8.76, 8.76),
#  'AbsAC40_uM': (0.08, 35.0),
#  'MIC90': (2.0, 128.0),
#  'ID/g': (4.9, 26.2),
#  'dTm': (9.1, 9.1),
#  'NonRGS-EC50 (uM)': (2.7, 16.08),
#  'K app ratio': (0.042, 2.1),
#  'M2/M1 Index': (1.5, 10.0),
#  'M2/M1 index': (0.1, 3.5),
#  'Agonist index': (5.4, 104.0),
#  'A1 selectivity': (0.02, 123.0),
#  'A2 selectivity': (0.0004, 36.0)}

# %%
# 4. Split the dataset into training, validation, and test sets
train_val_df, test_df = train_test_split(df, test_size=0.1, random_state=42)
train_df, val_df = train_test_split(train_val_df, test_size=0.1, random_state=42)

# Convert pandas DataFrames to Hugging Face Datasets
train_dataset = Dataset.from_pandas(train_df)
val_dataset = Dataset.from_pandas(val_df)
test_dataset = Dataset.from_pandas(test_df)

print("Example training sample:")
train_dataset[0]
# Out:
# Example training sample:
# {'Canonical SMILES': 'Cl.NCc1ccc(OCc2ccccc2OC(F)(F)F)cc1',
#  'Activity Type': 'Inhibition',
#  'Activity Value': 5.0,
#  'input_text': 'Cl.NCc1ccc(OCc2ccccc2OC(F)(F)F)cc1 | Activity Type: Inhibition',
#  'labels': 0.0010586885887195622,
#  '__index_level_0__': 460830}

# %%
# 5. Load the tokenizer from the checkpoint
checkpoint = "unikei/bert-base-smiles"
tokenizer = BertTokenizerFast.from_pretrained(checkpoint)

# %%
# 6. Set up model configuration for regression
config = BertConfig.from_pretrained(checkpoint)
config.num_labels = 1
config.problem_type = "regression"

# %%
# 6. Set up model configuration for regression
config = BertConfig.from_pretrained(checkpoint)
config.num_labels = 1
config.problem_type = "regression"

# %%
# 7. Set up BitsAndBytesConfig for 4-bit quantization (QLoRA-style)
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

# Load the model with 4-bit quantization enabled, placing the entire model on GPU 0
model = AutoModelForSequenceClassification.from_pretrained(
    checkpoint,
    config=config,
    quantization_config=quantization_config,
    device_map={"": 0}
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at unikei/bert-base-smiles and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# 8. Map data using the tokenizer
def tokenize_function(example):
    return tokenizer(example["input_text"], truncation=True, padding="max_length", max_length=128)

train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Set the format for PyTorch
train_dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
val_dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
test_dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
# Note: The original "Activity Type" column is still present in the dataset for grouping.
# Out:
# Map:   0%|          | 0/1185254 [00:00<?, ? examples/s]
# Map:   0%|          | 0/131695 [00:00<?, ? examples/s]
# Map:   0%|          | 0/146328 [00:00<?, ? examples/s]

# %%
# 9. Set up LoRA configuration using PEFT
lora_config = LoraConfig(
    task_type="SEQ_CLS",    # Sequence classification/regression
    r=8,
    lora_alpha=32,
    lora_dropout=0.1,
    target_modules=["query", "value"]
)
model = get_peft_model(model, lora_config)

# Optional: Cast trainable parameters (LoRA adapters) to FP32 for stability.
for param in model.parameters():
    if param.requires_grad:
        param.data = param.data.to(torch.float32)

# %%
# 10. Optionally integrate unsloth optimization if available.
if unsloth_available:
    try:
        model = optimize_model(model)
        print("Unsloth optimization applied.")
    except Exception as e:
        print("Error during unsloth optimization:", e)
else:
    print("Skipping unsloth optimization.")
# Out:
# Skipping unsloth optimization.

# %%
# 11. Print trainable parameters to verify
model.print_trainable_parameters()

# 12. Send model to GPU (if not already there)
model.to(device)
# Out:
# trainable params: 295,681 || all params: 109,377,794 || trainable%: 0.2703
# PeftModelForSequenceClassification(
#   (base_model): LoraModel(
#     (model): BertForSequenceClassification(
#       (bert): BertModel(
#         (embeddings): BertEmbeddings(
#           (word_embeddings): Embedding(30000, 768, padding_idx=0)
#           (position_embeddings): Embedding(512, 768)
#           (token_type_embeddings): Embedding(2, 768)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder): BertEncoder(
#           (layer): ModuleList(
#             (0-11): 12 x BertLayer(
#               (attention): BertAttention(
#                 (self): BertSdpaSelfAttention(
#                   (query): lora.Linear4bit(
#                     (base_layer): Linear4bit(in_features=768, out_features=768, bias=True)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=768, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=768, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (key): Linear4bit(in_features=768, out_features=768, bias=True)
#                   (value): lora.Linear4bit(
#                     (base_layer): Linear4bit(in_features=768, out_features=768, bias=True)
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=768, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=768, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                     (lora_magnitude_vector): ModuleDict()
#                   )
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): BertSelfOutput(
#                   (dense): Linear4bit(in_features=768, out_features=768, bias=True)
#                   (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): BertIntermediate(
#                 (dense): Linear4bit(in_features=768, out_features=3072, bias=True)
#                 (intermediate_act_fn): GELUActivation()
#               )
#               (output): BertOutput(
#                 (dense): Linear4bit(in_features=3072, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#         (pooler): BertPooler(
#           (dense): Linear4bit(in_features=768, out_features=768, bias=True)
#           (activation): Tanh()
#         )
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#       (classifier): ModulesToSaveWrapper(
#         (original_module): Linear(in_features=768, out_features=1, bias=True)
#         (modules_to_save): ModuleDict(
#           (default): Linear(in_features=768, out_features=1, bias=True)
#         )
#       )
#     )
#   )
# )

# %%
# 13. Define a custom Trainer to override compute_loss and remove the "num_items_in_batch" argument.
class CustomTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        kwargs.pop("num_items_in_batch", None)
        outputs = model(**inputs)
        loss = outputs.loss
        return (loss, outputs) if return_outputs else loss

# %%
# 14. Set training arguments
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="steps",
    eval_steps=500,
    save_steps=500,
    #max_steps=5,  # For quick testing; remove/increase for full training.
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    learning_rate=2e-5,
    weight_decay=0.01,
    logging_steps=100,
    load_best_model_at_end=True,
    metric_for_best_model="mse",
    fp16=True
)

# %%
# 15. Define regression metric (Mean Squared Error) manually.
def compute_metrics(eval_pred: EvalPrediction):
    predictions, labels = eval_pred
    predictions = predictions.flatten()
    mse_val = float(((predictions - labels) ** 2).mean())
    return {"mse": mse_val}

# %%
# 16. Data collator for dynamic padding
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
# 17. Initialize the custom Trainer.
trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# <ipython-input-29-bde3e3849869>:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `CustomTrainer.__init__`. Use `processing_class` instead.
#   trainer = CustomTrainer(

# %%
# 18. Evaluate Base Model on Test Set Before Fine-Tuning
print("Evaluating base model performance (before fine-tuning) on test dataset...")
base_test_metrics = trainer.evaluate(test_dataset)
print("Base model Test MSE:", base_test_metrics.get("mse", base_test_metrics.get("eval_mse")))

# Compute group-level accuracy for base model.
# Define tolerance for a prediction to be considered "accurate" (since labels are normalized 0-1).
tolerance = 0.1
base_preds_obj = trainer.predict(test_dataset)
base_preds = base_preds_obj.predictions.flatten()
base_labels = np.array(test_dataset["labels"])
activity_types = np.array(test_dataset["Activity Type"])  # original group info
unique_groups = np.unique(activity_types)

group_results = {}
for group in unique_groups:
    mask = (activity_types == group)
    count = np.sum(mask)
    if count > 0:
        # Accuracy: proportion of predictions with absolute error less than tolerance.
        acc = np.mean(np.abs(base_preds[mask] - base_labels[mask]) < tolerance)
        group_results[group] = {"base_accuracy": acc, "count": count}
    else:
        group_results[group] = {"base_accuracy": None, "count": 0}
# Out:
# Evaluating base model performance (before fine-tuning) on test dataset...
# Base model Test MSE: 0.006145087536424398

# %%
# 19. Fine-Tune the Model
print("Fine-tuning the model...")
trainer.train()
# Out:
# Fine-tuning the model...
#     <div>
#
#       <progress value='7001' max='222237' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  7001/222237 1:39:08 < 50:48:38, 1.18 it/s, Epoch 0.09/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Model Preparation Time</th>
#       <th>Mse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.011500</td>
#       <td>0.005637</td>
#       <td>0.001800</td>
#       <td>0.005637</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.010600</td>
#       <td>0.005139</td>
#       <td>0.001800</td>
#       <td>0.005139</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.010000</td>
#       <td>0.005374</td>
#       <td>0.001800</td>
#       <td>0.005374</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.009500</td>
#       <td>0.004796</td>
#       <td>0.001800</td>
#       <td>0.004796</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.011300</td>
#       <td>0.004891</td>
#       <td>0.001800</td>
#       <td>0.004891</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.011500</td>
#       <td>0.004510</td>
#       <td>0.001800</td>
#       <td>0.004510</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.008700</td>
#       <td>0.004748</td>
#       <td>0.001800</td>
#       <td>0.004748</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.008600</td>
#       <td>0.004584</td>
#       <td>0.001800</td>
#       <td>0.004584</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.007200</td>
#       <td>0.004535</td>
#       <td>0.001800</td>
#       <td>0.004535</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.008700</td>
#       <td>0.004565</td>
#       <td>0.001800</td>
#       <td>0.004565</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.007100</td>
#       <td>0.004097</td>
#       <td>0.001800</td>
#       <td>0.004097</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.008100</td>
#       <td>0.004247</td>
#       <td>0.001800</td>
#       <td>0.004247</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.008200</td>
#       <td>0.004112</td>
#       <td>0.001800</td>
#       <td>0.004112</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='6774' max='8231' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6774/8231 05:26 < 01:10, 20.73 it/s]
#     </div>

# %%
# 20. Evaluate Fine-Tuned Model on Test Set
print("Evaluating finetuned model performance (after fine-tuning) on test dataset...")
fine_test_metrics = trainer.evaluate(test_dataset)
print("Finetuned model Test MSE:", fine_test_metrics.get("mse", fine_test_metrics.get("eval_mse")))

fine_preds_obj = trainer.predict(test_dataset)
fine_preds = fine_preds_obj.predictions.flatten()

for group in unique_groups:
    mask = (activity_types == group)
    count = np.sum(mask)
    if count > 0:
        acc = np.mean(np.abs(fine_preds[mask] - base_labels[mask]) < tolerance)
        # Add the finetuned accuracy to our group results.
        group_results[group]["finetuned_accuracy"] = acc
    else:
        group_results[group]["finetuned_accuracy"] = None

# %%
# 21. Create a summary DataFrame for group-level accuracy and count.
group_df = pd.DataFrame(group_results).T  # Transpose so that rows are groups.
group_df.index.name = "Activity Type"
group_df = group_df.reset_index()

# Compute weighted average accuracy over groups.
total_count = group_df["count"].sum()
weighted_base = (group_df["base_accuracy"] * group_df["count"]).sum() / total_count
weighted_fine = (group_df["finetuned_accuracy"] * group_df["count"]).sum() / total_count

average_row = pd.DataFrame({
    "Activity Type": ["Average"],
    "base_accuracy": [weighted_base],
    "finetuned_accuracy": [weighted_fine],
    "count": [total_count]
})
group_df = pd.concat([group_df, average_row], ignore_index=True)

# Create a summary table comparing overall test MSE.
results_df = pd.DataFrame({
    "base-model": [base_test_metrics.get("mse", base_test_metrics.get("eval_mse"))],
    "finetuned-model": [fine_test_metrics.get("mse", fine_test_metrics.get("eval_mse"))]
}, index=["test_overall"])

# %%
print("\nOverall Test MSE Comparison:")
results_df

# %%
print("\nGroup-level Accuracy and Data Count on Test Dataset:")
group_df

# %%
#
